# %%
import tensorflow as tf

dir(tf)
# Out:
# 2025-07-20 12:35:07.972588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752995107.984367   20179 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752995107.987997   20179 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752995107.996820   20179 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
dir(tf.keras.layers.TFSMLayer)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_existing_weight',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_api_export_path',
#  '_api_export_symbol_id',
#  '_assert_input_compatibility',
#  '_build_at_init',
#  '_build_by_run_for_kwargs',
#  '_build_by_run_for_single_pos_arg',
#  '_check_quantize_args',
#  '_check_super_called',
#  '_checkpoint_adapter',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_copy_trackable_to_cpu',
#  '_default_save_signature',
#  '_deferred_dependencies',
#  '_delete_tracking',
# ...

# %%
tf.__file__
# Out:
# '/home/mana/.local/lib/python3.12/site-packages/tensorflow/__init__.py'

# %%
tf.keras.layers.__file__
# Out:
# '/home/mana/.local/lib/python3.12/site-packages/keras/_tf_keras/keras/layers/__init__.py'
